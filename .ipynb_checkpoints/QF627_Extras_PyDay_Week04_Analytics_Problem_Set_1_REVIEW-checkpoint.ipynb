# %% [markdown]
# # QF 627 Extras - Financial Analytics
# ## Problem Set `1` | `RE`view

# %% [markdown]
# > Hi Team! 👋
#
# > The questions will require you to perform `reverse-engineering` 🧩 Instead of receiving fully `written` questions, you will see `expected output` from certain lines of code, along with comments on semi-completed code. Your task is to fill in the missing input code to generate the given output. Engaging in this type of reverse-engineering exercise in computational programming will strengthen your knowledge and skills in analytics with Python.
#
# > The questions below won’t be too difficult, as each one includes a hint to guide you. My goal is not just to ask questions but also to provide additional learning pointers.
#
# > In class last night, I demonstrated the `lets-plot` library, which allows you to apply the principles of the `Grammar of Graphics` in financial analytics. Here, you'll see that the same type of plot can also be built using another library I mentioned in class: `plotnine`. While lets-plot provides interactive visualizations, plotnine generates static ones.
#
# > As you work through the current problem set, you'll deepen your understanding of the plotnine library and become more familiar with the functions and parameters used to create ***data*** visualizations powered by the Grammar of Graphics framework.
#
# > In our class, we emphasize `learning how to learn`, and we will experience that `learning by doing` is the most effective approach. I hope that working through this problem set helps reinforce your understanding 😊
#
# > Enjoy!

# %% [markdown]
# ### <font color = green> Setting `Dependencies`: Activation of necessary libraries </font>

# %%
import numpy as np # for numerical computation
import pandas as pd # for data wrangling for tabular data

from plotnine import * # for Grammar of Graphics Framework --> static data visualization
              # import everything
import warnings
warnings.filterwarnings("ignore")

# %%
# %whos
# Out:
# Variable                    Type        Data/Info
# -------------------------------------------------
# aes                         type        <class 'plotnine.mapping.aes.aes'>
# after_scale                 function    <function after_scale at 0x125d32480>
# after_stat                  function    <function after_stat at 0x125d322a0>
# annotate                    type        <class 'plotnine.geoms.annotate.annotate'>
# annotation_logticks         type        <class 'plotnine.geoms.an<...>cks.annotation_logticks'>
# annotation_stripes          type        <class 'plotnine.geoms.an<...>ipes.annotation_stripes'>
# arrow                       type        <class 'plotnine.geoms.geom_path.arrow'>
# as_labeller                 function    <function as_labeller at 0x1261e94e0>
# coord_cartesian             type        <class 'plotnine.coords.c<...>rtesian.coord_cartesian'>
# coord_equal                 type        <class 'plotnine.coords.coord_fixed.coord_fixed'>
# ...

# %% [markdown]
# ### <font color = green> Import the Datasets </font>

# %% [markdown]
# > There are two datasets provided for your answers to the current exercise problem set.
#
# - `product_metrics.csv`
#
# - `feature_usage.csv`

# %% [markdown]
# ```python
# product_metrics =\
# (
#     pd
#     .______("https://talktoroh.com/s/product_metrics.csv") # read_csv() reads data stored in CSV format
# )
# ```

# %%
product_metrics =\
(
    pd
    .read_csv("https://talktoroh.com/s/product_metrics.csv")
)

# %%
product_metrics
# Out:
#           date product_version platform  active_users  new_users  revenue  \
# 0   2024-01-01            v1.0      iOS           500         50     1000
# 1   2024-02-01            v1.0      iOS           550         60     1100
# 2   2024-03-01            v1.0      iOS           600         70     1200
# 3   2024-01-01            v1.0  Android           400         40      800
# 4   2024-02-01            v1.0  Android           420         45      900
# 5   2024-03-01            v1.0  Android           500         55      950
# 6   2024-01-01            v1.1      iOS           650         80     1300
# 7   2024-02-01            v1.1      iOS           700         85     1400
# 8   2024-03-01            v1.1      iOS           750         90     1500
# 9   2024-01-01            v1.1  Android           550         60      900
# 10  2024-02-01            v1.1  Android           600         65     1000
# 11  2024-03-01            v1.1  Android           650         70     1100
#
# ...

# %%
product_metrics.head(3)
# Out:
#          date product_version platform  active_users  new_users  revenue  \
# 0  2024-01-01            v1.0      iOS           500         50     1000
# 1  2024-02-01            v1.0      iOS           550         60     1100
# 2  2024-03-01            v1.0      iOS           600         70     1200
#
#    churn_rate country
# 0        0.05      US
# 1        0.04      US
# 2        0.03      US

# %%
product_metrics.tail(3)
# Out:
#           date product_version platform  active_users  new_users  revenue  \
# 9   2024-01-01            v1.1  Android           550         60      900
# 10  2024-02-01            v1.1  Android           600         65     1000
# 11  2024-03-01            v1.1  Android           650         70     1100
#
#     churn_rate country
# 9         0.06      AU
# 10        0.05      AU
# 11        0.04      AU

# %%
# product_metrics

# %%
feature_usage =\
(
    pd
    .read_csv("https://talktoroh.com/s/feature_usage.csv")
)

# %% [markdown]
# ```python
# feature_usage =\
# (
#     pd
#     .______("https://talktoroh.com/s/feature_usage.csv")
# )
# ```

# %%
feature_usage
# Out:
#           date        feature  usage_count user_type  satisfaction_score
# 0   2024-01-01         Search          100       All                 4.0
# 1   2024-02-01         Search          120       All                 4.2
# 2   2024-03-01         Search          150       All                 4.1
# 3   2024-04-01         Search          160       All                 4.3
# 4   2024-05-01         Search          180       All                 4.4
# 5   2024-06-01         Search          200       All                 4.5
# 6   2024-01-01  Notifications           80       All                 3.8
# 7   2024-02-01  Notifications           90       All                 3.9
# 8   2024-03-01  Notifications          100       All                 4.0
# 9   2024-04-01  Notifications          110       All                 4.1
# 10  2024-05-01  Notifications          120       All                 4.0
# 11  2024-06-01  Notifications          130       All                 4.2

# %%
# feature_usage

# %% [markdown]
# ### <font color = green> Question 1. Bar chart of `new_users` for each `country` </font> <font color = "blue"> [Analyze `product_metrics` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,       # Specify the dataset, e.g., product_metrics
#            aes(x = "____", # Which column should be on the x-axis?
#                y = "____", # Which column should be on the y-axis?
#                fill= "____") # Which column determines bar color?
#           )
#     + geom_col() # geometric columns
#     + scale_y_continuous(limits = [0, ____ ], # forces the y-axis to span from 0 to 300.
#                           breaks = np.arange(____, 350, ____ )
#                           # Replace the underscores to reflect the start and step.
#                           # If we want breaks at 50 intervals, you might use np.arange(0, 350, 50)
#                          )
#     + theme_minimal() # theme_minimal() gives a clean, minimalistic look
#     + theme(legend_position = _____ ) # theme(legend_position = False) hides the legend
# )
# ```

# %%
product_metrics.columns
# Out:
# Index(['date', 'product_version', 'platform', 'active_users', 'new_users',
#        'revenue', 'churn_rate', 'country'],
#       dtype='object')

# %% [markdown]
# ### <font color = red> Answer 1: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_1 =\
(
    ggplot(product_metrics, # Data set
           aes(x = "country", # Aesthetic Mapping
               y = "new_users",
               fill = "country") # by default, this will generate legend
          )
    + geom_col() # geometric features
                 # color = "blue"
                 # aes(fill = "country")
    + scale_y_continuous(limits = [0, 300], # [min, max] --> range
                         breaks = np.arange(0, 350, 50)
                        )
    + theme_minimal()
    + theme(legend_position = False)
)

# %%
answer_1

# %% [markdown]
# ### <font color = green> Question 2. Grouped bar chart where the x-axis is the product_version, the y-axis is active_users, and bars are grouped and colored by the platform</font> <font color = "blue"> [Analyze `product_metrics` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,                  # Name of the DataFrame, e.g., product_metrics
#            aes(x = "____",          # Which column on x-axis? e.g., product_version
#                y = "____",          # Numeric column for bar height? e.g., active_users
#                fill = "____")       # Which column to define bar color groups? e.g., platform
#           )
#     + geom_col(position = position_dodge(width = 0.9),
#                           # position_dodge() puts bars for the same x-category side by side.
#                color = "____")      # Outline color for the bars, e.g., "white"
#     + labs(title = "Active Users by Platform and Product Version",
#     # labs() Customize your title, subtitle, and axis labels.
#            subtitle = "____",       # Subtitle to give context, e.g., "Add Your Interpretation Here"
#            x = "____",              # Label for x-axis, e.g., "Product Version"
#            y = "____",              # Label for y-axis, e.g., "Active Users"
#            caption = "Prof. Roh's Problem Set 1 Data: Product Metrics")
#             # The caption can give credit or context to the source data.
#     + theme_538() # Applies a styling theme inspired by the FiveThirtyEight design.
#     + theme(legend_position = "____")  # Possible values: "top", "bottom", "left", "right", or "none"
# )
# ```

# %%
product_metrics.columns
# Out:
# Index(['date', 'product_version', 'platform', 'active_users', 'new_users',
#        'revenue', 'churn_rate', 'country'],
#       dtype='object')

# %%
product_metrics["product_version"].unique()
# Out:
# array(['v1.0', 'v1.1'], dtype=object)

# %%
product_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             12 non-null     object
#  1   product_version  12 non-null     object
#  2   platform         12 non-null     object
#  3   active_users     12 non-null     int64
#  4   new_users        12 non-null     int64
#  5   revenue          12 non-null     int64
#  6   churn_rate       12 non-null     float64
#  7   country          12 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 900.0+ bytes

# %%
product_metrics[["active_users"]].describe().T
# Out:
#               count   mean         std    min    25%    50%    75%    max
# active_users   12.0  572.5  106.951561  400.0  500.0  575.0  650.0  750.0

# %% [markdown]
# ### <font color = red> Answer 2: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_2 =\
(
    ggplot(product_metrics, 
           aes(x = "product_version",
               y = "active_users",
               fill = "platform")
          )
    + geom_col(position = position_dodge(width = 0.9),
               color = "white")
    + labs(title = "Active Users by Platform and Product Version",
           subtitle = "Add Your Interpretation Here",
           x = "Product Version",
           y = "Active Users",
           caption = "Prof. Roh's Problem Set 1 Data: Product Metrics")
    + theme_538()
    + theme(legend_position = "top")
)

# %%
answer_2

# %% [markdown]
# ### <font color = green> Question 3. Scatter plot showing the relationship between active_users (on the x-axis) and revenue (on the y-axis), with points colored by country </font> <font color = "blue"> [Analyze `product_metrics` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,                       # Which dataset is being used?
#            aes(x = "____",             # Which column is on the x-axis? e.g., "active_users"
#                y = "____",             # Which column is on the y-axis? e.g., "revenue"
#                color = "____")         # Which column should define the color grouping? e.g., "country"
#           )
#     + geom_point(size = ____)          # Numeric value for the point size, e.g., 3
#     + labs(title = "____")             # Main title for the plot, e.g., "Revenue vs. Active Users"
#     + theme_bw() # Applies a classic black-and-white theme.
#     + annotate(geom = "text",
#     # annotate() Places a text label on the plot at coordinates (x, y).
#     #            Useful for highlighting specific points or areas in the chart.
#                x = ____,               # Numeric value for the x-coordinate of the text annotation
#                y = ____,               # Numeric value for the y-coordinate of the text annotation
#                label = "____",         # The text label to be shown
#                color = "____")         # Color for the annotation text, e.g., "darkred"
# )
# ```

# %%
product_metrics.columns.to_frame()
# Out:
#                                0
# date                        date
# product_version  product_version
# platform                platform
# active_users        active_users
# new_users              new_users
# revenue                  revenue
# churn_rate            churn_rate
# country                  country

# %% [markdown]
# ### <font color = red> Answer 3: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_3 =\
(
    ggplot(product_metrics,
           aes(x = "active_users",
               y = "revenue",
 #             color = "country")
              )
           )
    + geom_point(aes(color = "country"),
                 size = 5
                )
    + labs(title = "Revenue vs. Active Users")
    + theme_bw() 
    + annotate(geom = "label",
               label = "Wow, Canada!",
               x = 650,
               y = 1400,
               color = "blue")
)

# %%
answer_3

# %% [markdown]
# ### <font color = green> Question 4. Distribution of user satisfaction scores </font> <font color = "blue"> [Analyze `feature_usage` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,                     # Which dataset? e.g., feature_usage
#            aes(x = "____")           # Column to visualize, e.g., "satisfaction_score"
#           )
#     + geom_histogram(bins = ____,           #  Number of bins for the histogram, e.g., 10
#                      fill = "____",         # Fill color, e.g., "dodgerblue"
#                      color = "____")        # Outline color, e.g., "white"
#     + geom_density(color = "____",          # Color for the density line, e.g., "red"
#                    size = ____)             # Size (thickness) of the line, e.g., 2
#     + labs(title = "Distribution of Satisfaction Scores",
#            x = "____")                     # Label for the x-axis, e.g., "Satisfaction Scores"
#     + scale_x_continuous(limits = [3.8, 4.6],
#                          breaks = np.arange(_____ , ____ , 0.1) # sets ticks at 0.1 increments.
#                         )
#     + theme_538()
#     + annotate(geom = "text",
#                x = ____,               # Numeric x position for the annotation, e.g., 4.4
#                y = ____,               # Numeric y position for the annotation, e.g., 2.5
#                label = "____",         # Annotation text, e.g., "Team, I am proud of you :)\nWell Done!!!"
#                color = "____")         # Color for the annotation text, e.g., "green"
# )
# ```

# %%
feature_usage.columns
# Out:
# Index(['date', 'feature', 'usage_count', 'user_type', 'satisfaction_score'], dtype='object')

# %% [markdown]
# ### <font color = red> Answer 4: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_4 =\
(
    ggplot(feature_usage,
           aes(x = "satisfaction_score")
          )
    + geom_histogram(bins = 10,
                     fill = "dodgerblue", # inner
                     color = "white") # outer
    + geom_density(color = "red",
                   size = 3)
    + scale_x_continuous(limits = [3.8, 4.6],
                         breaks = np.arange(3.8, 4.7, 0.1)
                         )
    + labs(title = "Distribution of User Satisfaction Scores",
           subtitle = "Scores are right skewed!",
           x = "Satisfaction Scores")
    + theme_538()
    + annotate(x = 4.4,
               y = 2,
               geom = "label",
               label = "Team, I am proud of you :)\nWell Done :)",
               color = "blue")
)

# %%
answer_4

# %% [markdown]
# ### <font color = green> Question 5. Box plot displaying how satisfaction scores vary by feature (each box plot represents one feature) </font> <font color = "blue"> [Analyze `feature_usage` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,            # Name of the dataset, e.g., feature_usage
#            aes(x = "____",    # Which column defines categories on the x-axis? e.g., "feature"
#                y = "____")    # Which numeric column for the y-axis? e.g., "satisfaction_score"
#           )
#     + geom_boxplot(aes(fill = "____") # geom_boxplot() creates one box per category on the x-axis
#                   )  # Which column determines the fill color? e.g., "feature"
#     + labs(title = "____",    # Title, e.g., "Satisfaction Score as a Function of Type of Feature"
#            subtitle = "____",           # Subtitle, e.g., "TYPE Your Interpretation HERE"
#            x = "____",                  # x-axis label, e.g., "Type of Feature"
#            y = "____"
#           )                  # y-axis label, e.g., "Satisfaction Score"
#     + theme_538()
#     + theme(legend_position = ____)     # Possible values: "top", "right", "bottom", False, etc.
# )

# %%
feature_usage.columns
# Out:
# Index(['date', 'feature', 'usage_count', 'user_type', 'satisfaction_score'], dtype='object')

# %% [markdown]
# ### <font color = red> Answer 5: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_5 =\
(
    ggplot(feature_usage,
           aes(x = "feature",
               y = "satisfaction_score")
          )
    + geom_boxplot(aes(fill = "feature"),
                   notch = True # returns Confidence Intervals for Box Plot --> Population Parameters of Median
                  )
    + labs(title = "Satisfaction Score as a Function of Type of Feature",
           subtitle = "Search > Notification",
           x = "Type of Feature",
           y = "Satisfaction Score")
    + theme_538()
    + theme(legend_position = False)
)

# %%
answer_5

# %% [markdown]
# ### <font color = green> Question 6. Line chart of usage_count by date for each feature </font> <font color = "blue"> [Analyze `feature_usage` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,               # Name of the dataset, e.g., feature_usage
#            aes(x = "____",     # Which column goes on the x-axis? e.g., "date"
#                y = "____",     # Which column goes on the y-axis? e.g., "usage_count"
#                group = "____") # Which column defines the grouping? e.g., "feature"
#           )
#     + geom_line(color = "____")  # Color for the line, e.g., "green"
#     + geom_point(color = "____") # Color for the points, e.g., "red"
#     + facet_grid(cols = "____")  # Which variable to facet by? e.g., "feature"
#                # cols = Used for column-wise faceting (one column per unique feature).
#     + labs(title = "Usage Count for Feature Type",
#            subtitle = "____",     # A brief subtitle, e.g., "The First Half of 2024 Over Time Trend"
#            x = "____",            # Label for the x-axis, e.g., "Date"
#            y = "____")            # Label for the y-axis, e.g., "Usage Count"
#     + theme_bw()
#     + theme(axis_text_x = element_text(angle = ____)
#                       #  Rotates x-axis text by 45 degrees, reducing overlap when there are many dates.
#            )
# )

# %%
feature_usage.columns
# Out:
# Index(['date', 'feature', 'usage_count', 'user_type', 'satisfaction_score'], dtype='object')

# %% [markdown]
# ### <font color = red> Answer 6: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_6 =\
(
    ggplot(feature_usage,
           aes(x = "date",
               y = "usage_count",
               group = "feature")
          ) 
    + geom_line(color = "green") # make sure to bring the point to the front
    + geom_point(color = "red",
                 size = 3)
    + facet_grid(cols = "feature")
    + labs(title = "Usage Count for Feature Type",
           subtitle = "The first half of 2024 over time trend", 
           x = "Date",
           y = "Usage Count",
           caption = "Source: Prof. Roh's Analytics Problem Set 1--Feature Usage Data")
    + theme_bw()
    + theme(axis_text_x = element_text(angle = 45)
           )
)

# %%
answer_6

# %% [markdown]
# ### <font color = green> Question 7. Scatter plot with a linear regression line illustrating the relationship between active_users and churn_rate, faceted by platform </font> <font color = "blue"> [Analyze `product_metrics` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,             # Your dataset, e.g., product_metrics
#            aes(x = "____",      # Column name for the x-axis, e.g., "active_users"
#                y = "____")      # Column name for the y-axis, e.g., "churn_rate"
#           )
#     + geom_point(size = ____,     # Numeric size of the points, e.g., 3
#                  color = "____")  # Color for the points, e.g., "red"
#     + stat_smooth(method = "____",   # Type of smoothing method, e.g., "lm"
#                   se = ____,         # Whether to display the confidence interval, e.g., False
#                   color = "____")    # Color for the smoothing line, e.g., "blue"
#     + facet_grid(cols = "____")      # Column name to facet by, e.g., "platform"
#     + labs(title = "____",   # Title, e.g., "The Relationships between Active Users and Churn Rate"
#            subtitle = "____",        # Subtitle text, e.g., "What's your thought?"
#            x = "____",               # Label for the x-axis, e.g., "Active Users"
#            y = "____",               # Label for the y-axis, e.g., "Churn Rate"
#            caption = "____"
#           ) # Caption text, e.g., "Source: Prof. Roh's Problem Set 1 `Product Metrics Dataset`"
#     + theme_bw()
# )
# ```

# %%
product_metrics.columns
# Out:
# Index(['date', 'product_version', 'platform', 'active_users', 'new_users',
#        'revenue', 'churn_rate', 'country'],
#       dtype='object')

# %%
product_metrics["platform"].unique()
# Out:
# array(['iOS', 'Android'], dtype=object)

# %% [markdown]
# ### <font color = red> Answer 7: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_7 =\
(
    ggplot(product_metrics,
           aes(x = "active_users",
               y = "churn_rate")
          ) 
    + geom_smooth(method = "lm",
                  se = False,
                  formula = "y ~ x",
                  color = "blue")
    + geom_point(color = "red",
                 size = 2.5)
    + facet_grid(cols = "platform")
    + labs(title = "The Relationships between Active Users and Churn Rate",
           subtitle = "What's your thought?",
           caption = "Source: Prof. Roh's PS 1 Dataset on Proudct Metrics",
           y = "Churn Rate",
           x = "Active Users")
    + theme_bw()
)

# %%
answer_7

# %% [markdown]
# ### <font color = green> Question 8. Lollipop chart </font> <font color = "blue"> [Analyze `product_metrics` dataset]

# %% [markdown]
# > You may copy and paste the code below into a code cell and plug in the necessary lines of code to complete the visualization.
# ```python
# (
#     ggplot(____,         # Name of your dataset, e.g., product_metrics
#            aes(y = "____",   # Categorical variable on the y-axis, e.g., "product_version"
#                x = "____")   # Numeric variable on the x-axis, e.g., "revenue"
#           )
#     + geom_segment(aes(x = 0,
#                        xend = "____", # xend should match the numeric x variable, e.g., "revenue"
#                        y="____",       # y should match the categorical variable
#                        yend="____"),   # yend matches the same categorical variable
#                    color="black"
#                   )
#     + geom_point(aes(color = "____"),  # Which column determines color, e.g., "product_version"
#                  size = ____)          # Numeric size for the point, e.g., 4
#     + labs(title = "____",  # Title text: If you wish to insert a new line, use "\n"
#            subtitle = "____ ",
#            x = "____",
#            y = "____")
#     + facet_grid(rows = "____",  # rows = row-wise facet
#                  cols = "____")  # cols = column-wise facet
#     + theme_bw()
#     + theme(legend_position = ____,  # "top", "right", "bottom", "none", or False to remove legend
#             text = element_text(font = "____")
#            )                  # Font name, e.g., "Courier" or "Courier New"
# )
# ```

# %%
product_metrics.columns
# Out:
# Index(['date', 'product_version', 'platform', 'active_users', 'new_users',
#        'revenue', 'churn_rate', 'country'],
#       dtype='object')

# %% [markdown]
# ### <font color = red> Answer 8: Please provide your lines of code below to replicate the visualization above. </font>

# %%
answer_8 =\
(
    ggplot(product_metrics, 
           aes(x = "revenue",
               y = "product_version")
          )
    + geom_segment(aes(x = 0,
                       xend = "revenue",
                       y = "product_version",
                       yend = "product_version")
                  )
    + geom_point(aes(color = "product_version"),
                 size = 5)
    + labs(title = "Regardless of platform and month,\nProudct Version 1.1 generated higher revenue.",
           subtitle = "Hmm... that's even more pronounced for the iOS platform.\nWhy might that be?",
           y = "Product Version (1.0 vs. 1.1)",
           x = "Total Revenue")
    + facet_grid(rows = "date",
                 cols = "platform")
    + theme_bw()
    + theme(text = element_text(font = "Courier"),
            legend_position = False)
)

# %%
answer_8

# %% [markdown]
# ### To Asmita

# %%
product_metrics["revenue"].describe()
# Out:
# count      12.000000
# mean     1095.833333
# std       215.805398
# min       800.000000
# 25%       937.500000
# 50%      1050.000000
# 75%      1225.000000
# max      1500.000000
# Name: revenue, dtype: float64

# %%
np.mean(product_metrics["revenue"]
       )
# Out:
# np.float64(1095.8333333333333)

# %%
divergent_lollipop =\
(
    ggplot(product_metrics, 
           aes(x = "revenue",
               y = "product_version")
          )
    + geom_segment(aes(x = np.mean(product_metrics["revenue"]
                                  ),
                       xend = "revenue",
                       y = "product_version",
                       yend = "product_version",
                       color = "product_version")
                  )
    + geom_point(aes(color = "product_version"),
                 size = 5)
    + geom_vline(xintercept = np.mean(product_metrics["revenue"]
                                     ),
                 color = "red"
                )
    + labs(title = "Regardless of platform and month,\nProudct Version 1.1 generated higher revenue.",
           subtitle = "Hmm... that's even more pronounced for the iOS platform.\nWhy might that be?",
           y = "Product Version (1.0 vs. 1.1)",
           x = "Total Revenue")
    + facet_grid(rows = "date",
                 cols = "platform")
    + theme_bw()
    + theme(text = element_text(font = "Courier"),
            legend_position = False)
)

# %%
divergent_lollipop

# %% [markdown]
# ### <font color="green">"Thank you for putting your efforts into the exercise problem sets 💯"</font>
